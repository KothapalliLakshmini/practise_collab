# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Problem statement:-
#
# The dataset provided contains information on the US honey consumption, including the
# average price of honey over the years. We aim to explore and analyze this data to
# identify the trends and patterns in the average honey price and gain insights into its
# fluctuation over time

# %% [markdown]
# ## US Honey Dataset — Column Description
#
# | Column Name           | Description |
# |----------------------|------------|
# | Unnamed              | Represents the index column. Not useful for analysis and can be dropped. |
# | state                | Name of the US state. |
# | colonies_number      | Total number of bee colonies in the state. |
# | yield_per_colony     | Average yield (or number of bees/honey produced) per colony. |
# | production           | Total honey production in the state. |
# | stocks               | Total stock of honey available in the state. |
# | average_price        | Average price of honey per year in each state. |
# | value_of_production  | Total value generated from honey production per year. |
# | year                 | Year of production. |

# %% [markdown]
# Using the provided dataset on US honey consumption, perform an exploratory data
# analysis to visualize and analyze the trends .

# %% [markdown]
# Address the following key questions in your analysis:
#  # 1) Which states are rarely contributing to honey production for the last 27 years?
#
# # 2) Which are the top 5 Honey producing states in the US ?
#
# # 3) What is the Change in mean Average price of Honey from 1995 to 2021?
#
# # 4) Which was the year when production of Honey in wholeUS was the highest?
#
# # 5) From the above inference we get the production was highest in the year 2000, now let infer which state was having highest contribution in that year
#
# # 6) Which states have the highest no. of colonies in the year 2000?

# %% [markdown]
# #DATASET
#
# - load dataset
# - info,decribe,head,tail,null,grouping
# -outliers

# %%
import pandas as pd #data manipulation
import numpy as np #math cal
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/US_honey_dataset.csv")

# %%
df
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 0              0       Alabama            16000                58      928000
# 1              1       Arizona            52000                79     4108000
# 2              2      Arkansas            50000                60     3000000
# 3              3    California           420000                93    39060000
# 4              4      Colorado            45000                60     2700000
# ...          ...           ...              ...               ...         ...
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0       state  colonies_number  yield_per_colony  production  \
# 0           0     Alabama            16000                58      928000
# 1           1     Arizona            52000                79     4108000
# 2           2    Arkansas            50000                60     3000000
# 3           3  California           420000                93    39060000
# 4           4    Colorado            45000                60     2700000
#
#     stocks  average_price  value_of_production  year
# 0    28000           62.0               575000  1995
# 1   986000           68.0              2793000  1995
# 2   900000           64.0              1920000  1995
# 3  4687000           60.0             23436000  1995
# 4  1404000           68.0              1836000  1995

# %%
df.tail()
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
#        stocks  average_price  value_of_production  year
# 1110    79000           8.23              1975000  2021
# 1111  1206000           2.52              7741000  2021
# 1112   136000           4.80              1238000  2021
# 1113   750000           2.81              5547000  2021
# 1114   242000           2.07              4562000  2021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1115 non-null   int64
#  1   state                1115 non-null   object
#  2   colonies_number      1115 non-null   int64
#  3   yield_per_colony     1115 non-null   int64
#  4   production           1115 non-null   int64
#  5   stocks               1115 non-null   int64
#  6   average_price        1115 non-null   float64
#  7   value_of_production  1115 non-null   int64
#  8   year                 1115 non-null   int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 78.5+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0  colonies_number  yield_per_colony    production  \
# count  1115.00000      1115.000000       1115.000000  1.115000e+03
# mean    557.00000     62438.565022         59.743498  2.851268e+06
# std     322.01708     92648.175955         19.940500  5.561202e+06
# min       0.00000      2000.000000         19.000000  1.200000e+04
# 25%     278.50000      9000.000000         45.000000  2.460000e+05
# 50%     557.00000     26000.000000         57.000000  8.280000e+05
# 75%     835.50000     69000.000000         71.000000  2.700000e+06
# max    1114.00000    550000.000000        155.000000  3.906000e+07
#
#              stocks  average_price  value_of_production         year
# count  1.115000e+03    1115.000000         1.115000e+03  1115.000000
# mean   1.172625e+06     140.623076         5.667412e+06  2007.740807
# std    2.049556e+06     107.011544         9.459460e+06     7.823002
# min    9.000000e+03       1.300000         1.060000e+05  1995.000000
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'state', 'colonies_number', 'yield_per_colony',
#        'production', 'stocks', 'average_price', 'value_of_production', 'year'],
#       dtype='object')

# %%
df
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 0              0       Alabama            16000                58      928000
# 1              1       Arizona            52000                79     4108000
# 2              2      Arkansas            50000                60     3000000
# 3              3    California           420000                93    39060000
# 4              4      Colorado            45000                60     2700000
# ...          ...           ...              ...               ...         ...
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
# ...

# %%
df['state'].value_counts()
# Out:
# state
# Alabama          27
# Arizona          27
# Arkansas         27
# California       27
# Colorado         27
# Florida          27
# Georgia          27
# Hawaii           27
# Idaho            27
# Illinois         27
# Indiana          27
# Iowa             27
# Kansas           27
# Louisiana        27
# Maine            27
# Michigan         27
# Mississippi      27
# Minnesota        27
# Montana          27
# Missouri         27
# NorthCarolina    27
# NewYork          27
# Nebraska         27
# NewJersey        27
# Pennsylvania     27
# Oregon           27
# Ohio             27
# NorthDakota      27
# Washington       27
# WestVirginia     27
# Vermont          27
# Virginia         27
# Tennessee        27
# SouthDakota      27
# Utah             27
# Texas            27
# Wisconsin        27
# Wyoming          27
# Kentucky         26
# NewMexico        18
# Nevada           15
# SouthCarolina    12
# Maryland          9
# Oklahoma          9
# ...

# %%
df.drop("Unnamed: 0",axis = 1,inplace = True)

# %%
df
# Out:
#              state  colonies_number  yield_per_colony  production   stocks  \
# 0          Alabama            16000                58      928000    28000
# 1          Arizona            52000                79     4108000   986000
# 2         Arkansas            50000                60     3000000   900000
# 3       California           420000                93    39060000  4687000
# 4         Colorado            45000                60     2700000  1404000
# ...            ...              ...               ...         ...      ...
# 1110      Virginia             6000                40       79000    79000
# 1111    Washington            96000                32     1206000  1206000
# 1112  WestVirginia             6000                43      136000   136000
# 1113     Wisconsin            42000                47      750000   750000
# 1114       Wyoming            38000                58      242000   242000
#
#       average_price  value_of_production  year
# ...

# %%
#null values

df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
#if incase if we have null values - df.dropna()

# %%
#duplicate values

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state                1115 non-null   object
#  1   colonies_number      1115 non-null   int64
#  2   yield_per_colony     1115 non-null   int64
#  3   production           1115 non-null   int64
#  4   stocks               1115 non-null   int64
#  5   average_price        1115 non-null   float64
#  6   value_of_production  1115 non-null   int64
#  7   year                 1115 non-null   int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 69.8+ KB

# %%
#outliers ?
sns.boxplot(data = df, x = "average_price")
# Out:
# <Axes: xlabel='average_price'>

# %%
df.columns
# Out:
# Index(['state', 'colonies_number', 'yield_per_colony', 'production', 'stocks',
#        'average_price', 'value_of_production', 'year'],
#       dtype='object')

# %%
for i in df.columns:
  if(df[i].dtype != "object"):
    plt.boxplot(df[i])
    plt.xlabel(i)
    plt.show()

# %%
#state  wise honey production
plt.figure(figsize = (10,8))
sns.barplot(x = "state",y = "production",data = df,palette= 'Set1')
plt.xticks(rotation = 90)
plt.show()
# Out:
# /tmp/ipykernel_8695/3046870532.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "state",y = "production",data = df,palette= 'Set1')

# %%
df.columns
# Out:
# Index(['state', 'colonies_number', 'yield_per_colony', 'production', 'stocks',
#        'average_price', 'value_of_production', 'year'],
#       dtype='object')

# %% [markdown]
#  2) Which are the top 5  & Honey producing states in the US ?

# %%
states_production = df.groupby('state')['production'].sum().reset_index()
#reset index is used becoz we ar eusing grroupby --- usage is to ignore any sort of index issues

# %%
states_production
# Out:
#             state  production
# 0         Alabama    14467000
# 1         Arizona    38844000
# 2        Arkansas    51846000
# 3      California   423876000
# 4        Colorado    32660000
# 5         Florida   280934000
# 6         Georgia    57426000
# 7          Hawaii    15420000
# 8           Idaho    87188000
# 9        Illinois     9864000
# 10        Indiana     9686000
# 11           Iowa    48607000
# 12         Kansas    14138000
# 13       Kentucky     3224000
# 14      Louisiana    60568000
# 15          Maine     4762000
# 16       Maryland     1975000
# 17       Michigan   101063000
# 18      Minnesota   176581000
# 19    Mississippi    21235000
# 20       Missouri    17904000
# 21        Montana   197173000
# 22       Nebraska    63655000
# 23         Nevada     7399000
# 24      NewJersey     6913000
# 25      NewMexico    10082000
# 26        NewYork    78444000
# 27  NorthCarolina     8909000
# 28    NorthDakota   513742000
# 29           Ohio    22485000
# ...

# %%
top_5 = states_production.nlargest(5,'production')
top_5
# Out:
#           state  production
# 28  NorthDakota   513742000
# 3    California   423876000
# 34  SouthDakota   355726000
# 5       Florida   280934000
# 21      Montana   197173000

# %%
top_5 = states_production.sort_values(by = 'production',ascending = False).head()
top_5
# Out:
#           state  production
# 28  NorthDakota   513742000
# 3    California   423876000
# 34  SouthDakota   355726000
# 5       Florida   280934000
# 21      Montana   197173000

# %%
bottom_5 = states_production.sort_values(by = 'production',ascending = True).head()
bottom_5
# Out:
#             state  production
# 16       Maryland     1975000
# 30       Oklahoma     2055000
# 33  SouthCarolina     2823000
# 13       Kentucky     3224000
# 15          Maine     4762000

# %% [markdown]
# 3) What is the Change in mean Average price of Honey from 1995 to 2021?

# %%
year price.mean()
# Out:
#   File "/tmp/ipykernel_8695/2766518776.py", line 1
#     year price.mean()
#          ^
# SyntaxError: invalid syntax

# %%
mean_avg = df.groupby('year')['average_price'].mean().reset_index()
mean_avg
# Out:
#     year  average_price
# 0   1995      74.840909
# 1   1996      99.568182
# 2   1997      91.325581
# 3   1998      83.720930
# 4   1999      80.325581
# 5   2000      79.023256
# 6   2001      88.465116
# 7   2002     133.204545
# 8   2003     151.068182
# 9   2004     132.350000
# 10  2005     116.341463
# 11  2006     134.341463
# 12  2007     140.170732
# 13  2008     160.878049
# 14  2009     176.195122
# 15  2010     192.900000
# 16  2011     216.725000
# 17  2012     236.700000
# 18  2013     260.717949
# 19  2014     282.025000
# 20  2015     292.625000
# 21  2016     291.925000
# 22  2017     302.775000
# 23  2018       3.083500
# 24  2019       2.925500
# 25  2020       3.050000
# 26  2021       3.334250

# %%
change_mean =  mean_avg.iloc[0]- mean_avg.iloc[26]
change_mean
# Out:
# year            -26.000000
# average_price    71.506659
# dtype: float64

# %%
#heatmap - correlation map

corr = df.corr(numeric_only= True)
corr
# Out:
#                      colonies_number  yield_per_colony  production    stocks  \
# colonies_number             1.000000          0.201100    0.736643  0.800533
# yield_per_colony            0.201100          1.000000    0.413410  0.344385
# production                  0.736643          0.413410    1.000000  0.807947
# stocks                      0.800533          0.344385    0.807947  1.000000
# average_price              -0.165758         -0.187149   -0.194206 -0.173171
# value_of_production         0.905332          0.210358    0.520972  0.689202
# year                        0.034168         -0.327413   -0.284939 -0.113179
#
#                      average_price  value_of_production      year
# colonies_number          -0.165758             0.905332  0.034168
# yield_per_colony         -0.187149             0.210358 -0.327413
# production               -0.194206             0.520972 -0.284939
# stocks                   -0.173171             0.689202 -0.113179
# ...

# %%
sns.heatmap(corr, annot = True, cmap = 'coolwarm')
plt.show()

# %%
# #which plot when we ahve to use

# - barplot - cat vs num - states vs product
# -scatter plot - num vs num - age vs salary
# -box - outliers
# -pie - prop - cat vs num
# -line - trends - cat vs num
# - histogram - x - axis - data distribution
#violin - density plot
#pairplot - col vs col
